# %%
import sys

# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# %env CHIME_FRB_ACCESS_TOKEN=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjoia3NoaW4iLCJleHAiOjE2NzQ2NzIwNTAsImlzcyI6ImZyYi1tYXN0ZXIiLCJpYXQiOjE2NzQ2NzAyNTB9.SVi_M7bCD8EiqwWCLBgvWrGIqYQNikWqd0JSm_mlbNM
# %env CHIME_FRB_REFRESH_TOKEN=a6fab3e271f6af7cfdfa21b512ac9c79788d937f9dd9d983

# %matplotlib inline
import numpy as np
from matplotlib.pyplot import *

import importlib
import datetime
import glob
import h5py
import sys
import os
import pickle
import scipy.constants
import scipy.linalg as la
import scipy.constants

from ch_util import ephemeris, tools, rfi, andata, data_index
import baseband_analysis.core as bbcore
from baseband_analysis import utilities
from baseband_analysis import utilities
from baseband_analysis.analysis import beamform
import baseband_analysis.utilities as bbtools
from ch_util.fluxcat import FluxCatalog


from IPython.core.display import Image 
from rfi_shion_version import clean_persistent_rfi


def get_norm_power(tied_beam, downsample_factor):
    N_times = tied_beam.shape[-1]
    N_ds_times = N_times//downsample_factor
    beam_power_ds = np.abs(tied_beam[..., :N_ds_times*downsample_factor]) ** 2
    s = beam_power_ds.shape
    beam_power_ds.shape = s[:-1] + (N_ds_times, downsample_factor)
    beam_power_ds = np.mean(beam_power_ds, -1)
    power_mean = np.nanmean(beam_power_ds, axis=-1)
    power_std = np.nanstd(beam_power_ds, axis=-1)
    # Center around 0 and normalize to have unit std
    beam_power_ds -= power_mean[..., np.newaxis]
    beam_power_ds /= power_std[..., np.newaxis]
    return beam_power_ds
# Out:
# env: CHIME_FRB_ACCESS_TOKEN=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjoia3NoaW4iLCJleHAiOjE2NzQ2NzIwNTAsImlzcyI6ImZyYi1tYXN0ZXIiLCJpYXQiOjE2NzQ2NzAyNTB9.SVi_M7bCD8EiqwWCLBgvWrGIqYQNikWqd0JSm_mlbNM
# env: CHIME_FRB_REFRESH_TOKEN=a6fab3e271f6af7cfdfa21b512ac9c79788d937f9dd9d983
# /opt/pysetup/.venv/lib/python3.8/site-packages/ch_util/data_index.py:12: UserWarning: The ch_util.data_index module is deprecated.
#   warnings.warn("The ch_util.data_index module is deprecated.")

# %% [markdown]
# # Look at digital gains first, flag bands where gains are low (rfi is large enough to saturate range)

# %%
f_MHz = np.linspace(800, 400, 1024, endpoint=False)
rfi_mask = rfi.frequency_mask(f_MHz).astype(np.int)
hf = figure(num=1, figsize=(10, 4))
matplotlib.rcParams.update({'font.size': 16})
plot(f_MHz, rfi_mask)
title('RFI mask')
xlabel('Frequency (MHz)')
np.sum(rfi_mask), np.sum(rfi_mask)/len(f_MHz)
# Out:
# /tmp/ipykernel_5598/2584430728.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rfi_mask = rfi.frequency_mask(f_MHz).astype(np.int)
# (346, 0.337890625)

# %%
dig_gain_filename = '/arc/projects/chime_frb/shiona/rfi_analysis/20191211T131503Z_chime_digitalgain/00003478.h5'#'20231003T215051Z_KKO_digitalgain/00070511.h5'
ant = 1000
f_MHz = np.linspace(800, 400, 1024, endpoint=False)

hf = figure(num=1, figsize=(10, 4))
matplotlib.rcParams.update({'font.size': 14})
plot(f_MHz, 20*np.log10(1/dig_gain[:, ant].real))
ymin, ymax = gca().get_ylim()
xlabel('Frequency (MHz)')
ylabel('dB')
title('(Inverse) Digital gain for antenna %i\nfrom %s'%(ant, dig_gain_filename))
gca().fill_between(f_MHz, ymin, ymax, where=rfi_mask > 0, facecolor='grey', alpha=0.4, interpolate=True)
ylim(ymin, ymax)
#xlim(720, 760)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       5 hf = figure(num=1, figsize=(10, 4))
#       6 matplotlib.rcParams.update({'font.size': 14})
# ----> 7 plot(f_MHz, 20*np.log10(1/dig_gain[:, ant].real))
#       8 ymin, ymax = gca().get_ylim()
#       9 xlabel('Frequency (MHz)')
#
# NameError: name 'dig_gain' is not defined

# %%
acq_name = 'baseband_65547659'
acq_date = '20191219'
acq_base_folder = '/arc/projects/chime_frb/data/chime/baseband/raw/2019/12/19/astro_65547659/'

d1 = datetime.datetime.strptime(acq_date + "+0000", 
                                '%Y%m%d' + '%z')

datafiles = glob.glob(os.path.join(acq_base_folder, '*.h5'))

rfi_channels=np.where(read_rfi_mask>0)[0]
print(rfi_channels)

read_clean_mask = np.zeros_like(rfi_mask)

clean_freq_ids=np.where(read_clean_mask>0)[0]
print(clean_freq_ids)

m=np.array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
        True,  True,  True, False, False, False, False, False, False,
       False, False, False, False, False, False])
x=[]
for i in range(5):
    if i<3:
        for j in range(5):
            x.append(freqs[i][j])
    else:
        for j in range(4):
            x.append(freqs[i][j])

read_rfi_mask = rfi.frequency_mask(np.array(x))
read_rfi_mask

read_freq_bins=np.append(rfi_channels,clean_freq_ids)
datafiles_all = [os.path.join(acq_base_folder, '%s_%i.h5'%(acq_name, fb)) 
             for fb in read_freq_bins]




hf = figure(num=1, figsize=(10, 4))
matplotlib.rcParams.update({'font.size': 14})
plot(f_MHz, 20*np.log10(1/dig_gain[:, ant].real))
ymin, ymax = gca().get_ylim()
xlabel('Frequency (MHz)')
ylabel('dB')
title('(Inverse) Digital gain for antenna %i\nfrom %s'%(ant, dig_gain_filename))
gca().fill_between(f_MHz, ymin, ymax, where=rfi_mask > 0, facecolor='grey', alpha=0.4, interpolate=True)
read_rfi_mask = np.zeros_like(rfi_mask)
read_rfi_mask[[fb for fb in read_freq_bins if rfi_mask[fb]]] = True

read_clean_mask[[fb for fb in read_freq_bins if not rfi_mask[fb]]] = True
gca().fill_between(f_MHz, ymin, ymax, where=rfi_mask > 0, facecolor='grey', alpha=0.4, interpolate=True)
gca().fill_between(f_MHz, ymin, ymax, where=read_rfi_mask > 0, facecolor='red', alpha=0.4, interpolate=True)
gca().fill_between(f_MHz, ymin, ymax, where=read_clean_mask > 0, facecolor='green', alpha=0.4, interpolate=True)
legend_elements = [matplotlib.patches.Patch(facecolor='grey', edgecolor='k', alpha=0.4, label='Static RFI mask'),
                   matplotlib.patches.Patch(facecolor='red', edgecolor='k', alpha=0.4, label='Selected RFI band'),
                   matplotlib.patches.Patch(facecolor='green', edgecolor='k', alpha=0.4, label='Selected clean band')]
legend(handles=legend_elements)
ylim(ymin, ymax)
xlim(700, 790)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       5 d1 = datetime.datetime.strptime(acq_date + "+0000",
#       6                                 '%Y%m%d' + '%z')
#       8 datafiles = glob.glob(os.path.join(acq_base_folder, '*.h5'))
# ---> 10 rfi_channels=np.where(read_rfi_mask>0)[0]
#      11 print(rfi_channels)
#      13 read_clean_mask = np.zeros_like(rfi_mask)
#
# NameError: name 'read_rfi_mask' is not defined

# %%
# Point source gains
gain_file = '/arc/projects/chime_frb/data/chime/daily_gain_solutions/hdf5_files/gain_20191219T033146.226812Z_casa_ref_cyga.h5'
DM = 464.50
ra_src = 226.2196451
dec_src = 85.39110717

# %%
from baseband_analysis import utilities
from baseband_analysis.analysis import beamform
import baseband_analysis.core.calibration as cal



gains = cal.read_gains(gain_file)

DM = 464.50
ra_src = 226.2196451
dec_src = 85.39110717

datas=[]
freqs=[]
for i in range((5)):
    print('%s: Reading files. Start' %(time.strftime('%Y%m%dT%H%M%S')))
    data = bbcore.BBData.from_acq_h5(datafiles_all[i*5:i*5+5])
    freqs.append(data.freq)
    print('%s: Reading files. End' %(time.strftime('%Y%m%dT%H%M%S')))
    datafiles
    cal.apply_calibration(data, gains)#, inputs=inputs)
    # using recipe from Daniele. Do not understand why apply_calibration conjugates the gains before applying them
    #utilities.apply_calibration(data, utilities.read_gains(gain_file))


    #Beamform
    beamform.tied_array(data, [ra_src], [dec_src], DM=DM)#, telescope_rotation=-0.088)
    del data["baseband"]
    datas.append(data)
# Out:
# 20231123T152241: Reading files. Start
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 17
#      15 for i in range((5)):
#      16     print('%s: Reading files. Start' %(time.strftime('%Y%m%dT%H%M%S')))
# ---> 17     data = bbcore.BBData.from_acq_h5(datafiles_all[i*5:i*5+5])
#      18     freqs.append(data.freq)
#      19     print('%s: Reading files. End' %(time.strftime('%Y%m%dT%H%M%S')))
#
# NameError: name 'datafiles_all' is not defined

# %%
len(datafiles_all)
# Out:
# 0

# %%
print(freqs[0])
freqs=np.array(freqs)
freqs=freqs.flatten()
freqs[-1].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(freqs[0])
#       2 freqs=np.array(freqs)
#       3 freqs=freqs.flatten()
#
# NameError: name 'freqs' is not defined

# %%
# Out:
# 23

# %%
import baseband_analysis.core.bbdata as bbdata

beamformed = bbdata.concatenate(datas)

# %%
from baseband_analysis.core.dedispersion import coherent_dedisp

bb_dedisp = coherent_dedisp(beamformed, DM)
# Write dedispersed data into the beamformed object to use it by default
if bb_dedisp is not None:
    beamformed['tiedbeam_baseband'][:] = bb_dedisp
downsample_factor = 256
N_ds_times = N_times//downsample_factor
beam_power_ds = get_norm_power(beamformed['tiedbeam_baseband'], downsample_factor)
beam_power_ds.shape
missing_freqs_index=12
N_missing_freqs
# Out:
# 464.5 464.5 0

# %%
hf = figure(num=1, figsize=(20, 12))
matplotlib.rcParams.update({'font.size': 20})

vmin, vmax = -3, 20
for pp in range(2):
    subplot(2, 1, pp+1)
    imshow(np.insert(beam_power_ds[:, pp], (missing_freqs_index,)*N_missing_freqs, np.nan, axis=0), 
           cmap='viridis', interpolation='nearest', aspect='auto', 
           origin='lower', #extent=[0, (N_ds_times-1)*2.56e-3*downsample_factor, f_MHz[0], f_MHz[-1]], 
           vmin=vmin, vmax=vmax)
    cb = colorbar()
    cb.set_label('Normalized power')
    title('YY' if data['tiedbeam_locations']['pol'][pp].astype(str)=='S' else 'XX')
    xlabel('Time (ms)')
    ylabel('Frequency (MHz)') 

suptitle('Beamformed and dedispersed data from %s\nDownsample factor = %i'
         %(acq_name, downsample_factor), y=1.05)
tight_layout()

# %% [markdown]
# # Repeat but remove rfi band

# %%
read_freq_bins=[170]
datafiles_all = [os.path.join(acq_base_folder, '%s_%i.h5'%(acq_name, fb)) 
             for fb in read_freq_bins]
datafiles_all=['/arc/projects/chime_frb/data/chime/baseband/raw/2023/11/04/astro_333356311/baseband_333356311_33.h5']

# %%
import pandas as pd
#inputs=pd.read_pickle('/arc/home/shiona/parrot.pkl')
inputs[0].pol
# Out:
# 'S'

# %%
clean_persistent_rfi(data, ra_src, dec_src, cyl_rotation=-0.088, ps_gain_file=gain_file,
                     rfi_channels=[170])#np.where(read_rfi_mask)[0], calibrate_data=False, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 clean_persistent_rfi(data, ra_src, dec_src, cyl_rotation=-0.088, ps_gain_file=gain_file,
#       2                      rfi_channels=[170])#np.where(read_rfi_mask)[0], calibrate_data=False, verbose=True)
#
# File ~/rfi_shion_version.py:85, in clean_persistent_rfi(bbdata, ra_target, dec_target, cyl_rotation, ps_gain_file, rfi_channels, calibrate_data, inputs, telescope, verbose)
#      83     print("%s: Reading inputs from database" %(time.strftime("%Y%m%dT%H%M%S")))
#      84 if inputs is None:
# ---> 85     cor_inputs_db = tools.get_correlator_inputs(date0[0],
#      86                     correlator=telescope)
#      87 else:
#      88     cor_inputs_db=inputs
#
# File /opt/pysetup/.venv/lib/python3.8/site-packages/ch_util/tools.py:1385, in get_correlator_inputs(lay_time, correlator, connect)
# ...

# %%
datas=[]
import datetime
date = datetime.datetime.now()
for i in range((5)):
    print('%s: Reading files. Start' %(time.strftime('%Y%m%dT%H%M%S')))
    data = bbcore.BBData.from_acq_h5(datafiles_all[0])#[i*5:i*5+5])
    print('%s: Reading files. End' %(time.strftime('%Y%m%dT%H%M%S')))
    
    #inputs = tools.get_correlator_inputs(date, correlator="FCC")

    #cal.apply_calibration(data, gains, inputs=inputs)
    # using recipe from Daniele. Do not understand why apply_calibration conjugates the gains before applying them
    #utilities.apply_calibration(data, utilities.read_gains(gain_file))

    
    clean_persistent_rfi(data, ra_src, dec_src, cyl_rotation=-0.088, ps_gain_file=gain_file,inputs=inputs,
                         rfi_channels=[170])#np.where(read_rfi_mask)[0], calibrate_data=False, verbose=True)


    #Beamform
    beamform.tied_array(data, [ra_src], [dec_src], DM=DM)#, telescope_rotation=-0.088)
    del data["baseband"]
    datas.append(data)
beamformed_rfi_cleaned = bbcore.bbdata.concatenate(datas)
# Out:
# 20231122T223348: Reading files. Start
# 20231122T223349: Reading files. End
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# Using feeds in the chime correlator
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[66], line 21
#      16 clean_persistent_rfi(data, ra_src, dec_src, cyl_rotation=-0.088, ps_gain_file=gain_file,inputs=inputs,
#      17                      rfi_channels=[170])#np.where(read_rfi_mask)[0], calibrate_data=False, verbose=True)
#      20 #Beamform
# ...

# %%
beamformed_rfi_cleaned = bbcore.bbdata.concatenate(datas)

# %%
# Sampling frequency, in Hz.
adc_sampling_freq = float(800e6)

# Number of samples in the inital FFT in the F-engine.
fpga_num_samp_fft = 2048
# f-engine parameters for alias sampling in second Nyquist zone.
fpga_num_freq = fpga_num_samp_fft // 2
fpga_freq0_mhz = adc_sampling_freq / 1e6
fpga_delta_freq_mhz = -adc_sampling_freq / 2 / fpga_num_freq / 1e6
fpga_delta_freq_mhz
# Out:
# -0.390625

# %%
from scipy.fftpack import fft, ifft

def delay_across_the_band(DM, freq_low=400, freq_high=800):
    """
    Return the delay in seconds caused by dispersion, given
    a Dispersion Measure (DM) in cm-3 pc, and the emitted
    frequency (freq_emitted) of the pulsar in MHz.

    Parameters
    ----------
    DM: float
    freq_low: float
        Lowest observing frequency in MHz.
    freq_high: float
        Highest observing frequency in MHz.

    """
    return k_DM * DM * (1.0 / freq_low ** 2 - 1.0 / freq_high ** 2)


#from baseband_analysis.core.dedispersion import incoherent_dedisp, coherent_dedisp
def get_nDM(DM, f0, dt=2.56e-6):
    df = -0.390625 #1/2.56#abs(common_utils.fpga_delta_freq_mhz)
    return (
        int(
            (
                np.ceil(
                    delay_across_the_band(DM, f0 - df / 2, f0 + df / 2)
                    / dt
                )
            ).max()
        )
        // 2
        + 1
    )

def pow2(x):
    return (1 << (x - 1).bit_length()) - x
k_DM = 1.0 / 2.41e-4

def coherent_dedisp(data, DM=None):
    # data is a BBdata instance
    if DM is None:
        DM = data["tiedbeam_baseband"].attrs["DM"]
    f0 = data.index_map["freq"]["centre"][:, np.newaxis]
    df = abs(fpga_delta_freq_mhz)
    ctime = data["time0"]["fpga_count"].astype(float) - data["time0"]["fpga_count"][
        -1
    ].astype(float)
    ctime = data.attrs["delta_time"] * ctime[:, np.newaxis]
    nDM = get_nDM(DM, f0, dt=data.attrs["delta_time"])
    fill = pow2(data.ntime + nDM * 2)
    shape = list(data["tiedbeam_baseband"].shape)
    shape[-1] += fill + nDM * 2
    t = np.zeros(shape, dtype=np.complex64)
    ntime = data.ntime
    matrix = data["tiedbeam_baseband"][:]
    mask = np.isnan(matrix)
    matrix[mask] = 0
    t[..., fill // 2 : fill // 2 + ntime] = matrix
    f = np.fft.fftfreq(t.shape[-1], d=data.attrs["delta_time"] * 1e6)
    H = np.exp(
        + 2j * np.pi * 1e6 * k_DM * DM * f ** 2 / (f + f0) / f0 ** 2  # Intrachannel de-dispersion
#        - 2j * np.pi * 1e6 * (f + f0) * (ctime - common_utils.k_DM * DM * (1 / f0 ** 2 - 1 / f0[-1] ** 2))  # Time shift to align the signal
    )[:, np.newaxis]
    dedispersed_array = ifft(fft(t) * H)[..., fill // 2 : fill // 2 + ntime]
    dedispersed_array[mask] = np.nan
    return dedispersed_array

# Coherent dedispersion
bb_dedisp = coherent_dedisp(beamformed_rfi_cleaned, DM)
# Write dedispersed data into the beamformed object to use it by default
if bb_dedisp is not None:
    beamformed_rfi_cleaned['tiedbeam_baseband'][:] = bb_dedisp

# %%
downsample_factor = 256
N_ds_times = N_times//downsample_factor
beam_power_ds = get_norm_power(beamformed_rfi_cleaned['tiedbeam_baseband'], downsample_factor)
beam_power_ds.shape
# Out:
# (24, 2, 470)

# %%
hf = figure(num=1, figsize=(20, 12))
matplotlib.rcParams.update({'font.size': 20})

vmin, vmax = -3, 20
for pp in range(2):
    subplot(2, 1, pp+1)
    imshow(np.insert(beam_power_ds[:, pp], (missing_freqs_index,)*N_missing_freqs, np.nan, axis=0), 
           cmap='viridis', interpolation='nearest', aspect='auto', 
           origin='lower', extent=[0, (N_ds_times-1)*2.56e-3*downsample_factor, f_MHz[0], f_MHz[-1]], 
           vmin=vmin, vmax=vmax)
    cb = colorbar()
    cb.set_label('Normalized power')
    title('YY' if data['tiedbeam_locations']['pol'][pp].astype(str)=='S' else 'XX')
    xlabel('Time (ms)')
    ylabel('Frequency (MHz)') 

suptitle('Beamformed, dedispersed, and RFI cleaned data from %s\nDownsample factor = %i'
         %(acq_name, downsample_factor), y=1.05)
tight_layout()

# %%
hf = figure(num=1, figsize=(20, 10))
matplotlib.rcParams.update({'font.size': 22})
rfi_channels=[167, 168, 169, 170,171,172,173,174,175,176,177,178]

time_index_frb_ds = 225
xlims = [210, 240]
ylims = [-3, 20]
for pp in range(2):
    subplot(2, 2, 2*pp+1)
    clean=[]
    for fb in range(N_freqs):
        np.where(read_rfi_mask)[0]
        x=beamformed_rfi_cleaned.index_map['freq']['id'][fb]
        if x not in rfi_channels:
            clean.append(beam_power_ds[fb, pp])
            plot(beam_power_ds[fb, pp], color='grey', alpha=0.6)
    clean=np.array(clean)
    plot(np.mean(clean, axis=0), color='blue', lw=2)
    grid()
    axvline(x=time_index_frb_ds, ls='--', color='k')
    ylabel('YY' if data['tiedbeam_locations']['pol'][pp].astype(str)=='S' else 'XX')
    xlim(xlims[0], xlims[1])
    ylim(ylims[0], ylims[1])
    if pp==0:
        title('Clean frequencies')
        gca().set_xticklabels([])
    else:
        xlabel('time index (downsampled)')
    
    subplot(2, 2, 2*pp+2)
    rfi_vals=[]
    for fb in range(N_freqs):
        x=beamformed_rfi_cleaned.index_map['freq']['id'][fb]
        if x in rfi_channels:
            rfi_vals.append(beam_power_ds[fb, pp])
            plot(beam_power_ds[fb, pp], color='grey', alpha=0.6)
    rfi_vals=np.array(rfi_vals)
    plot(np.mean(rfi_vals, axis=0), color='blue', lw=2)
    grid()
    axvline(x=time_index_frb_ds, ls='--', color='k')    
    xlim(xlims[0], xlims[1])
    ylim(ylims[0], ylims[1])
    if pp==0:
        title('RFI frequencies')
        gca().set_xticklabels([])
    else:
        xlabel('time index (downsampled)')
    
suptitle('Beamformed, dedispersed, and RFI cleaned data from %s\nDownsample factor = %i'
         %(acq_name, downsample_factor), y=1.05)
tight_layout()

# %%
date0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 date0
#
# NameError: name 'date0' is not defined

# %%
data = bbcore.BBData.from_acq_h5(datafiles_all[i*5:i*5+5])

# %%
from ch_util import ephemeris, tools

gain = cal.read_gains(gain_file) # Read gains
freq_id_list = data.index_map["freq"]["id"]
gain = gain[freq_id_list] # Gains for freqs in bbdata
gain_reordered = gain[:, data.input["chan_id"]] # reordered gains
good_inputs_index = np.where(abs(gain_reordered[fb])>0.)[0]
cor_inputs_db = tools.get_correlator_inputs(date0[0],
                        correlator="chime")

good_inputs = data.input["chan_id"][good_inputs_index]
good_inputs_index_x = np.array([good_inputs_index[ii] for ii in
                                range(len(good_inputs_index)) if
                                cor_inputs_db[good_inputs[ii]].pol=="E"])
good_inputs_index_y = np.array([good_inputs_index[ii] for ii in
                                range(len(good_inputs_index)) if
                                cor_inputs_db[good_inputs[ii]].pol=="S"])
good_inputs_index = [good_inputs_index_x, good_inputs_index_y]

# %%
good_inputs = [data.input["chan_id"][gii] for gii in good_inputs_index]
N_good_inputs = [len(good_inputs[pp]) for pp in range(2)]

# %%
N_vis = [(N_good_inputs[pp]*(N_good_inputs[pp]+1))//2 for pp in range(2)]

# %%
pp=0
fb=0
ra_target=ra_src
dec_target=dec_src
nan_index = np.where(np.isnan(abs(data.baseband[fb, 0])))[0]
NN = nan_index[0] if len(nan_index)>0 else N_times
    
timestamp0 = data["time0"]["ctime"] + data["time0"]["ctime_offset"]
date0 = [datetime.datetime.utcfromtimestamp(t) for t in timestamp0]
timestamp = timestamp0[:, np.newaxis] + data.time[np.newaxis, :]

timestamp_vis = np.array([timestamp[fb, NN//2]])
ra_vis = ephemeris.lsa(timestamp_vis)
ha_vis = np.radians(ra_vis - ra_target)

prod_map = [np.empty(N_vis[pp], dtype=[("input_a", "u2"), ("input_b", "u2")])
                    for pp in range(2)]
for pp in range(2):
    # row and col indices for upper triangular matrix
    row_index, col_index = np.triu_indices(N_good_inputs[pp])
    prod_map[pp]["input_a"], prod_map[pp]["input_b"] = row_index, col_index

# Form position vectors
tools.change_chime_location(rotation=-0.088)
feed_pos = [tools.get_feed_positions([cor_inputs_db[i] for i in good_inputs[pp]],
                                     get_zpos=False)
            for pp in range(2)]
baseline_x = [mat2utvec(feed_pos[pp][:, 0][np.newaxis, :] -
                        feed_pos[pp][:, 0][:, np.newaxis]) #upper trinagular matrix holding d_ij (x axis)
              for pp in range(2)]
baseline_y = [mat2utvec(feed_pos[pp][:, 1][np.newaxis, :] -
                        feed_pos[pp][:, 1][:, np.newaxis]) #upper trinagular matrix holding d_ij (y axis)
              for pp in range(2)]
wv = scipy.constants.c * 1e-6 / f_MHz[fb]
u = [baseline_x[pp] / wv for pp in range(2)] #n wavelengths
v = [baseline_y[pp] / wv for pp in range(2)]

# %%
fs_phase = tools.fringestop_phase(ha_vis, np.radians(ephemeris.CHIMELATITUDE),
                                                  np.radians(dec_target), u[pp], v[pp], 0.)

vis = [mat2utvec(np.tensordot(data.baseband[fb, good_inputs_index[pp], :NN],
                                      data.baseband[fb, good_inputs_index[pp], :NN].conj(),
                                      axes=([-1], [-1]))) / NN
               for pp in range(2)]

# %%
S = utvec2mat(N_good_inputs[pp], fs_phase.conj()) #reshape to ninputsxninputs
F = utvec2mat(N_good_inputs[pp], vis[pp])
F
# Out:
# array([[ 4.63104527e+00+0.j        , -2.89939495e-01+0.24146046j,
#         -8.87711246e-02+0.05605675j, ...,  1.67744628e-03-0.00360526j,
#         -3.57187565e-03+0.00465679j, -7.80304611e-03-0.00063426j],
#        [-2.89939495e-01-0.24146046j,  4.63532652e+00+0.j        ,
#          7.97329439e-02-0.36744419j, ...,  4.52326309e-03+0.00913833j,
#          1.69163363e-02-0.00743584j,  1.56311287e-02+0.00926351j],
#        [-8.87711246e-02-0.05605675j,  7.97329439e-02+0.36744419j,
#          4.72979762e+00+0.j        , ...,  3.74713123e-03+0.01710828j,
#          3.78051325e-03-0.00428124j,  2.17984561e-02+0.00305445j],
#        ...,
#        [ 1.67744628e-03+0.00360526j,  4.52326309e-03-0.00913833j,
#          3.74713123e-03-0.01710828j, ...,  4.74473607e+00+0.j        ,
#          2.28691842e-01+0.42021281j, -5.51971625e-02+0.09915293j],
#        [-3.57187565e-03-0.00465679j,  1.69163363e-02+0.00743584j,
#          3.78051325e-03+0.00428124j, ...,  2.28691842e-01-0.42021281j,
# ...

# %%
evalues, P = la.eigh(S, F)

# %%
data.baseband.shape
# Out:
# (4, 2048, 119825)

# %%
evalsS,p=la.eigh(S)
print(evalsS.shape)

evalsF,pF=la.eigh(F)
print(evalsF.shape)

e,pv=la.eigh(S,F)
print(e.shape)


e_SUM,pv=la.eigh(S+F)
print(e.shape)
# Out:
# (1000,)
# (1000,)
# (1000,)
# (1000,)

# %%
F.shape
# Out:
# (1000, 1000)

# %%
evalsF.shape
# Out:
# (1000,)

# %%
pF.shape
# Out:
# (1000, 1000)

# %%
e.shape, pv.shape
# Out:
# ((1000,), (1000, 1000))

# %%
P_dagger = P.T.conj()
P_dagger_inv = la.inv(P_dagger)
P_dagger_inv[:, -1].shape
# Out:
# (1000,)

# %%
P_dagger_inv[:].shape
# Out:
# (1000, 1000)

# %%
P_dagger[-1].shape
# Out:
# (1000,)
